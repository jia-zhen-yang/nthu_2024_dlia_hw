# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DL_HW/heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
# <ipython-input-8-39abb612ef0e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-8-39abb612ef0e>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-8-39abb612ef0e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
# <ipython-input-8-39abb612ef0e>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41    0   1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65    1   0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44    1   1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54    1   2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51    1   3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 268   40    1   0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60    1   0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64    1   2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43    1   0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57    1   0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185    0.685185    0.962963  131.525926  245.607407    0.151852
# std      9.149713    0.465305    1.023206   17.904675   51.529411    0.359544
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.250000    0.000000    0.000000  120.000000  210.250000    0.000000
# 50%     56.000000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.522222  149.807407    0.333333    1.024074    1.400000    0.744444
# std      0.529314   23.217253    0.472280    1.188379    0.618188    1.037166
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  134.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.600000    1.000000    0.000000
# 75%      1.000000  167.750000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  270.000000  270.000000
# mean     2.300000    0.544444
# std      0.623874    0.498946
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## 調整的hyper-parameter : epochs
#
# ## C. Training the Neural Network
#
# ## D. Evaluating Your Trained Model

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Tue Mar 19 12:35:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# read test file
test_data = pd.read_csv('/content/drive/MyDrive/DL_HW/heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

epochs_values = [20,50,100]
train_losses_compare = []
val_losses_compare = []
train_accuracies_compare = []
val_accuracies_compare = []
test_losses_compare = []
test_accuracies_compare = []


for i,epochs in enumerate(epochs_values):
  train_losses = []
  val_losses = []
  train_accuracies = []
  val_accuracies = []

  model = Model()

  best_val_loss = float('inf')
  best_val_acc = -1

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=1e-3)
  lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

  for epoch in tqdm(range(epochs)):
      # Training
      model.train()
      total_loss = 0.0
      train_correct = 0
      total_train_samples = 0

      for features, labels in train_loader:
          features = features.cuda()
          labels = labels.cuda()

          outputs = model(features)

          loss = criterion(outputs, labels)
          total_loss += loss.item()

          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          train_predicted = outputs.argmax(-1)
          train_correct += (train_predicted == labels).sum().item()
          total_train_samples += labels.size(0)

      # Learning rate update
      lr_scheduler.step()

      avg_train_loss = total_loss / len(train_loader)
      train_accuracy = 100. * train_correct / total_train_samples

      # Validation
      model.eval()
      total_val_loss = 0.0
      correct = 0
      total = 0
      with torch.no_grad():
          for features, labels in val_loader:
              features = features.cuda()
              labels = labels.cuda()

              outputs = model(features)

              loss = criterion(outputs, labels)
              total_val_loss += loss.item()

              predicted = outputs.argmax(-1)
              correct += (predicted == labels).sum().item()
              total += labels.size(0)

      avg_val_loss = total_val_loss / len(val_loader)
      val_accuracy = 100. * correct / total

      # Checkpoint
      if avg_val_loss < best_val_loss:
          best_val_loss = avg_val_loss

      if val_accuracy > best_val_acc:
          best_val_acc = val_accuracy
          torch.save(model.state_dict(), 'model_classification.pth')

      print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

      # Store performance
      train_losses.append(avg_train_loss)
      train_accuracies.append(train_accuracy)
      val_losses.append(avg_val_loss)
      val_accuracies.append(val_accuracy)

  # Load the trained weights
  model.load_state_dict(torch.load('model_classification.pth'))

  # Set the model to evaluation mode
  model.eval()

  test_correct = 0
  test_total = 0
  total_test_loss = 0
  with torch.no_grad():
      for features, labels in test_loader:

          features = features.cuda()
          labels = labels.cuda()

          outputs = model(features)

          loss = criterion(outputs, labels)
          total_test_loss += loss.item()

          predicted = outputs.argmax(-1)
          test_correct += (predicted == labels).sum().item()
          test_total += labels.size(0)

  train_losses_compare.append(train_losses)
  train_accuracies_compare.append(train_accuracies)
  val_losses_compare.append(val_losses)
  val_accuracies_compare.append(val_accuracies)

  test_losses_compare.append(total_test_loss / len(test_loader))
  test_accuracies_compare.append(100.0* test_correct / test_total)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1/20, Train loss: 5.6216, Train acc: 53.4392%, Val loss: 8.7072, Val acc: 45.6790%, Best Val loss: 8.7072 Best Val acc: 45.68%
# Epoch 2/20, Train loss: 5.3757, Train acc: 48.6772%, Val loss: 4.8546, Val acc: 54.3210%, Best Val loss: 4.8546 Best Val acc: 54.32%
# Epoch 3/20, Train loss: 2.4023, Train acc: 58.7302%, Val loss: 2.8386, Val acc: 50.6173%, Best Val loss: 2.8386 Best Val acc: 54.32%
# Epoch 4/20, Train loss: 1.6614, Train acc: 65.6085%, Val loss: 2.5710, Val acc: 55.5556%, Best Val loss: 2.5710 Best Val acc: 55.56%
# Epoch 5/20, Train loss: 1.3080, Train acc: 65.6085%, Val loss: 1.6838, Val acc: 58.0247%, Best Val loss: 1.6838 Best Val acc: 58.02%
# Epoch 6/20, Train loss: 0.9919, Train acc: 71.4286%, Val loss: 1.4332, Val acc: 59.2593%, Best Val loss: 1.4332 Best Val acc: 59.26%
# Epoch 7/20, Train loss: 0.8685, Train acc: 63.4921%, Val loss: 0.9532, Val acc: 65.4321%, Best Val loss: 0.9532 Best Val acc: 65.43%
# Epoch 8/20, Train loss: 0.7712, Train acc: 68.7831%, Val loss: 0.7971, Val acc: 65.4321%, Best Val loss: 0.7971 Best Val acc: 65.43%
# Epoch 9/20, Train loss: 0.6462, Train acc: 71.4286%, Val loss: 0.7288, Val acc: 70.3704%, Best Val loss: 0.7288 Best Val acc: 70.37%
# Epoch 10/20, Train loss: 0.6525, Train acc: 70.8995%, Val loss: 0.7191, Val acc: 67.9012%, Best Val loss: 0.7191 Best Val acc: 70.37%
# Epoch 11/20, Train loss: 0.6260, Train acc: 71.4286%, Val loss: 0.8962, Val acc: 58.0247%, Best Val loss: 0.7191 Best Val acc: 70.37%
# Epoch 12/20, Train loss: 0.6256, Train acc: 66.6667%, Val loss: 0.7507, Val acc: 62.9630%, Best Val loss: 0.7191 Best Val acc: 70.37%
# Epoch 13/20, Train loss: 0.5911, Train acc: 73.0159%, Val loss: 0.7384, Val acc: 65.4321%, Best Val loss: 0.7191 Best Val acc: 70.37%
# Epoch 14/20, Train loss: 0.5625, Train acc: 70.3704%, Val loss: 0.6823, Val acc: 69.1358%, Best Val loss: 0.6823 Best Val acc: 70.37%
# Epoch 15/20, Train loss: 0.5312, Train acc: 74.0741%, Val loss: 0.7010, Val acc: 67.9012%, Best Val loss: 0.6823 Best Val acc: 70.37%
# Epoch 16/20, Train loss: 0.5404, Train acc: 74.0741%, Val loss: 0.6665, Val acc: 69.1358%, Best Val loss: 0.6665 Best Val acc: 70.37%
# Epoch 17/20, Train loss: 0.5298, Train acc: 75.1323%, Val loss: 0.6656, Val acc: 69.1358%, Best Val loss: 0.6656 Best Val acc: 70.37%
# Epoch 18/20, Train loss: 0.5286, Train acc: 72.4868%, Val loss: 0.6774, Val acc: 66.6667%, Best Val loss: 0.6656 Best Val acc: 70.37%
# Epoch 19/20, Train loss: 0.5245, Train acc: 71.9577%, Val loss: 0.6729, Val acc: 67.9012%, Best Val loss: 0.6656 Best Val acc: 70.37%
# Epoch 20/20, Train loss: 0.5215, Train acc: 73.0159%, Val loss: 0.6710, Val acc: 67.9012%, Best Val loss: 0.6656 Best Val acc: 70.37%
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 1/50, Train loss: 8.7084, Train acc: 47.6190%, Val loss: 8.9362, Val acc: 54.3210%, Best Val loss: 8.9362 Best Val acc: 54.32%
# Epoch 2/50, Train loss: 5.6607, Train acc: 49.7354%, Val loss: 5.7111, Val acc: 45.6790%, Best Val loss: 5.7111 Best Val acc: 54.32%
# Epoch 3/50, Train loss: 3.4211, Train acc: 53.4392%, Val loss: 2.6224, Val acc: 54.3210%, Best Val loss: 2.6224 Best Val acc: 54.32%
# Epoch 4/50, Train loss: 2.1054, Train acc: 55.0265%, Val loss: 1.0193, Val acc: 64.1975%, Best Val loss: 1.0193 Best Val acc: 64.20%
# Epoch 5/50, Train loss: 1.6475, Train acc: 61.9048%, Val loss: 1.5432, Val acc: 61.7284%, Best Val loss: 1.0193 Best Val acc: 64.20%
# Epoch 6/50, Train loss: 1.4507, Train acc: 58.7302%, Val loss: 2.2190, Val acc: 55.5556%, Best Val loss: 1.0193 Best Val acc: 64.20%
# Epoch 7/50, Train loss: 1.4293, Train acc: 59.7884%, Val loss: 1.2554, Val acc: 62.9630%, Best Val loss: 1.0193 Best Val acc: 64.20%
# Epoch 8/50, Train loss: 0.8933, Train acc: 68.2540%, Val loss: 0.9270, Val acc: 65.4321%, Best Val loss: 0.9270 Best Val acc: 65.43%
# Epoch 9/50, Train loss: 0.7615, Train acc: 68.7831%, Val loss: 0.9719, Val acc: 60.4938%, Best Val loss: 0.9270 Best Val acc: 65.43%
# Epoch 10/50, Train loss: 0.6918, Train acc: 70.3704%, Val loss: 0.7711, Val acc: 67.9012%, Best Val loss: 0.7711 Best Val acc: 67.90%
# Epoch 11/50, Train loss: 0.6075, Train acc: 69.3122%, Val loss: 0.7175, Val acc: 67.9012%, Best Val loss: 0.7175 Best Val acc: 67.90%
# Epoch 12/50, Train loss: 0.6200, Train acc: 69.8413%, Val loss: 1.0057, Val acc: 59.2593%, Best Val loss: 0.7175 Best Val acc: 67.90%
# Epoch 13/50, Train loss: 0.6089, Train acc: 68.7831%, Val loss: 0.6726, Val acc: 74.0741%, Best Val loss: 0.6726 Best Val acc: 74.07%
# Epoch 14/50, Train loss: 0.5079, Train acc: 74.0741%, Val loss: 0.6482, Val acc: 70.3704%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 15/50, Train loss: 0.5560, Train acc: 71.4286%, Val loss: 0.8368, Val acc: 61.7284%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 16/50, Train loss: 0.6952, Train acc: 65.0794%, Val loss: 0.6817, Val acc: 65.4321%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 17/50, Train loss: 0.6141, Train acc: 67.7249%, Val loss: 1.1762, Val acc: 55.5556%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 18/50, Train loss: 0.7054, Train acc: 66.1376%, Val loss: 0.6548, Val acc: 70.3704%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 19/50, Train loss: 0.5482, Train acc: 68.7831%, Val loss: 0.7386, Val acc: 64.1975%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 20/50, Train loss: 0.6033, Train acc: 69.8413%, Val loss: 0.8640, Val acc: 59.2593%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 21/50, Train loss: 0.6276, Train acc: 67.1958%, Val loss: 0.7715, Val acc: 64.1975%, Best Val loss: 0.6482 Best Val acc: 74.07%
# Epoch 22/50, Train loss: 0.5223, Train acc: 70.3704%, Val loss: 0.6216, Val acc: 70.3704%, Best Val loss: 0.6216 Best Val acc: 74.07%
# Epoch 23/50, Train loss: 0.4985, Train acc: 74.6032%, Val loss: 0.6593, Val acc: 66.6667%, Best Val loss: 0.6216 Best Val acc: 74.07%
# Epoch 24/50, Train loss: 0.5238, Train acc: 73.0159%, Val loss: 0.8234, Val acc: 58.0247%, Best Val loss: 0.6216 Best Val acc: 74.07%
# Epoch 25/50, Train loss: 0.5803, Train acc: 69.3122%, Val loss: 0.6683, Val acc: 69.1358%, Best Val loss: 0.6216 Best Val acc: 74.07%
# Epoch 26/50, Train loss: 0.5055, Train acc: 72.4868%, Val loss: 0.6299, Val acc: 71.6049%, Best Val loss: 0.6216 Best Val acc: 74.07%
# Epoch 27/50, Train loss: 0.4749, Train acc: 74.6032%, Val loss: 0.6134, Val acc: 70.3704%, Best Val loss: 0.6134 Best Val acc: 74.07%
# Epoch 28/50, Train loss: 0.4560, Train acc: 74.6032%, Val loss: 0.6338, Val acc: 70.3704%, Best Val loss: 0.6134 Best Val acc: 74.07%
# Epoch 29/50, Train loss: 0.4660, Train acc: 74.6032%, Val loss: 0.6135, Val acc: 70.3704%, Best Val loss: 0.6134 Best Val acc: 74.07%
# Epoch 30/50, Train loss: 0.4668, Train acc: 75.1323%, Val loss: 0.6179, Val acc: 70.3704%, Best Val loss: 0.6134 Best Val acc: 74.07%
# Epoch 31/50, Train loss: 0.4562, Train acc: 75.6614%, Val loss: 0.5952, Val acc: 75.3086%, Best Val loss: 0.5952 Best Val acc: 75.31%
# Epoch 32/50, Train loss: 0.4569, Train acc: 76.7196%, Val loss: 0.5975, Val acc: 71.6049%, Best Val loss: 0.5952 Best Val acc: 75.31%
# Epoch 33/50, Train loss: 0.4677, Train acc: 75.6614%, Val loss: 0.6218, Val acc: 70.3704%, Best Val loss: 0.5952 Best Val acc: 75.31%
# Epoch 34/50, Train loss: 0.4489, Train acc: 78.3069%, Val loss: 0.5911, Val acc: 72.8395%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 35/50, Train loss: 0.4628, Train acc: 77.2487%, Val loss: 0.6272, Val acc: 70.3704%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 36/50, Train loss: 0.4990, Train acc: 75.1323%, Val loss: 0.5971, Val acc: 74.0741%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 37/50, Train loss: 0.4775, Train acc: 74.6032%, Val loss: 0.5945, Val acc: 71.6049%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 38/50, Train loss: 0.4649, Train acc: 75.6614%, Val loss: 0.6145, Val acc: 72.8395%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 39/50, Train loss: 0.4493, Train acc: 77.7778%, Val loss: 0.5963, Val acc: 71.6049%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 40/50, Train loss: 0.4409, Train acc: 76.1905%, Val loss: 0.6155, Val acc: 70.3704%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 41/50, Train loss: 0.4562, Train acc: 77.7778%, Val loss: 0.6082, Val acc: 72.8395%, Best Val loss: 0.5911 Best Val acc: 75.31%
# Epoch 42/50, Train loss: 0.4335, Train acc: 77.7778%, Val loss: 0.5884, Val acc: 75.3086%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 43/50, Train loss: 0.4416, Train acc: 77.2487%, Val loss: 0.5893, Val acc: 72.8395%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 44/50, Train loss: 0.4422, Train acc: 75.1323%, Val loss: 0.6021, Val acc: 72.8395%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 45/50, Train loss: 0.4376, Train acc: 78.3069%, Val loss: 0.5957, Val acc: 70.3704%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 46/50, Train loss: 0.4376, Train acc: 76.7196%, Val loss: 0.5918, Val acc: 72.8395%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 47/50, Train loss: 0.4376, Train acc: 76.1905%, Val loss: 0.5923, Val acc: 71.6049%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 48/50, Train loss: 0.4369, Train acc: 76.1905%, Val loss: 0.5930, Val acc: 70.3704%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 49/50, Train loss: 0.4354, Train acc: 76.7196%, Val loss: 0.5928, Val acc: 70.3704%, Best Val loss: 0.5884 Best Val acc: 75.31%
# Epoch 50/50, Train loss: 0.4360, Train acc: 76.7196%, Val loss: 0.5928, Val acc: 70.3704%, Best Val loss: 0.5884 Best Val acc: 75.31%
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 6.2991, Train acc: 51.8519%, Val loss: 1.3239, Val acc: 55.5556%, Best Val loss: 1.3239 Best Val acc: 55.56%
# Epoch 2/100, Train loss: 2.0778, Train acc: 52.9101%, Val loss: 1.9802, Val acc: 55.5556%, Best Val loss: 1.3239 Best Val acc: 55.56%
# Epoch 3/100, Train loss: 1.4865, Train acc: 53.9683%, Val loss: 0.9609, Val acc: 64.1975%, Best Val loss: 0.9609 Best Val acc: 64.20%
# Epoch 4/100, Train loss: 0.7753, Train acc: 66.1376%, Val loss: 0.7642, Val acc: 66.6667%, Best Val loss: 0.7642 Best Val acc: 66.67%
# Epoch 5/100, Train loss: 0.7014, Train acc: 67.7249%, Val loss: 0.6877, Val acc: 65.4321%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 6/100, Train loss: 0.6143, Train acc: 70.8995%, Val loss: 0.7085, Val acc: 65.4321%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 7/100, Train loss: 0.8932, Train acc: 61.3757%, Val loss: 0.7014, Val acc: 59.2593%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 8/100, Train loss: 0.9498, Train acc: 67.1958%, Val loss: 1.0146, Val acc: 60.4938%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 9/100, Train loss: 0.7592, Train acc: 70.8995%, Val loss: 1.1681, Val acc: 55.5556%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 10/100, Train loss: 0.7406, Train acc: 68.2540%, Val loss: 1.1763, Val acc: 58.0247%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 11/100, Train loss: 0.8226, Train acc: 65.0794%, Val loss: 1.1855, Val acc: 58.0247%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 12/100, Train loss: 0.7170, Train acc: 63.4921%, Val loss: 1.2147, Val acc: 56.7901%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 13/100, Train loss: 0.8050, Train acc: 65.6085%, Val loss: 1.2399, Val acc: 55.5556%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 14/100, Train loss: 0.8679, Train acc: 61.9048%, Val loss: 0.7984, Val acc: 61.7284%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 15/100, Train loss: 0.7734, Train acc: 68.7831%, Val loss: 0.7367, Val acc: 61.7284%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 16/100, Train loss: 0.5345, Train acc: 69.3122%, Val loss: 0.9296, Val acc: 60.4938%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 17/100, Train loss: 0.6352, Train acc: 69.8413%, Val loss: 1.1976, Val acc: 56.7901%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 18/100, Train loss: 0.7031, Train acc: 66.6667%, Val loss: 0.9229, Val acc: 59.2593%, Best Val loss: 0.6877 Best Val acc: 66.67%
# Epoch 19/100, Train loss: 0.6209, Train acc: 72.4868%, Val loss: 0.6495, Val acc: 67.9012%, Best Val loss: 0.6495 Best Val acc: 67.90%
# Epoch 20/100, Train loss: 0.5156, Train acc: 74.6032%, Val loss: 0.8209, Val acc: 62.9630%, Best Val loss: 0.6495 Best Val acc: 67.90%
# Epoch 21/100, Train loss: 0.5638, Train acc: 66.6667%, Val loss: 0.6153, Val acc: 70.3704%, Best Val loss: 0.6153 Best Val acc: 70.37%
# Epoch 22/100, Train loss: 0.5010, Train acc: 73.5450%, Val loss: 0.7522, Val acc: 61.7284%, Best Val loss: 0.6153 Best Val acc: 70.37%
# Epoch 23/100, Train loss: 0.7233, Train acc: 65.0794%, Val loss: 1.0893, Val acc: 55.5556%, Best Val loss: 0.6153 Best Val acc: 70.37%
# Epoch 24/100, Train loss: 0.7242, Train acc: 66.1376%, Val loss: 0.6633, Val acc: 71.6049%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 25/100, Train loss: 0.7042, Train acc: 65.0794%, Val loss: 0.6959, Val acc: 71.6049%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 26/100, Train loss: 0.6013, Train acc: 73.0159%, Val loss: 0.7074, Val acc: 70.3704%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 27/100, Train loss: 0.4973, Train acc: 74.0741%, Val loss: 0.8192, Val acc: 64.1975%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 28/100, Train loss: 0.4939, Train acc: 76.1905%, Val loss: 0.6503, Val acc: 71.6049%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 29/100, Train loss: 0.4440, Train acc: 77.7778%, Val loss: 0.6262, Val acc: 71.6049%, Best Val loss: 0.6153 Best Val acc: 71.60%
# Epoch 30/100, Train loss: 0.4807, Train acc: 75.1323%, Val loss: 0.5978, Val acc: 72.8395%, Best Val loss: 0.5978 Best Val acc: 72.84%
# Epoch 31/100, Train loss: 0.5749, Train acc: 77.2487%, Val loss: 0.5871, Val acc: 74.0741%, Best Val loss: 0.5871 Best Val acc: 74.07%
# Epoch 32/100, Train loss: 0.6497, Train acc: 66.6667%, Val loss: 0.6028, Val acc: 75.3086%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 33/100, Train loss: 0.6290, Train acc: 70.3704%, Val loss: 0.8769, Val acc: 60.4938%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 34/100, Train loss: 0.5707, Train acc: 72.4868%, Val loss: 0.6301, Val acc: 71.6049%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 35/100, Train loss: 0.4333, Train acc: 77.7778%, Val loss: 0.8249, Val acc: 60.4938%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 36/100, Train loss: 0.5531, Train acc: 70.3704%, Val loss: 0.7402, Val acc: 65.4321%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 37/100, Train loss: 0.4288, Train acc: 78.3069%, Val loss: 0.6855, Val acc: 69.1358%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 38/100, Train loss: 0.4630, Train acc: 75.6614%, Val loss: 0.9605, Val acc: 59.2593%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 39/100, Train loss: 0.4839, Train acc: 76.1905%, Val loss: 0.6934, Val acc: 65.4321%, Best Val loss: 0.5871 Best Val acc: 75.31%
# Epoch 40/100, Train loss: 0.4211, Train acc: 82.5397%, Val loss: 0.5862, Val acc: 72.8395%, Best Val loss: 0.5862 Best Val acc: 75.31%
# Epoch 41/100, Train loss: 0.4381, Train acc: 76.1905%, Val loss: 0.8087, Val acc: 60.4938%, Best Val loss: 0.5862 Best Val acc: 75.31%
# Epoch 42/100, Train loss: 0.4930, Train acc: 75.1323%, Val loss: 0.8342, Val acc: 60.4938%, Best Val loss: 0.5862 Best Val acc: 75.31%
# Epoch 43/100, Train loss: 0.5419, Train acc: 69.8413%, Val loss: 0.6518, Val acc: 71.6049%, Best Val loss: 0.5862 Best Val acc: 75.31%
# Epoch 44/100, Train loss: 0.6021, Train acc: 70.8995%, Val loss: 0.6032, Val acc: 71.6049%, Best Val loss: 0.5862 Best Val acc: 75.31%
# Epoch 45/100, Train loss: 0.4452, Train acc: 78.3069%, Val loss: 0.5609, Val acc: 74.0741%, Best Val loss: 0.5609 Best Val acc: 75.31%
# Epoch 46/100, Train loss: 0.3936, Train acc: 83.5979%, Val loss: 0.5781, Val acc: 76.5432%, Best Val loss: 0.5609 Best Val acc: 76.54%
# Epoch 47/100, Train loss: 0.4135, Train acc: 80.4233%, Val loss: 0.6578, Val acc: 70.3704%, Best Val loss: 0.5609 Best Val acc: 76.54%
# Epoch 48/100, Train loss: 0.4291, Train acc: 77.7778%, Val loss: 1.1966, Val acc: 58.0247%, Best Val loss: 0.5609 Best Val acc: 76.54%
# Epoch 49/100, Train loss: 0.6389, Train acc: 68.2540%, Val loss: 0.5599, Val acc: 75.3086%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 50/100, Train loss: 0.4777, Train acc: 74.6032%, Val loss: 0.7720, Val acc: 64.1975%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 51/100, Train loss: 0.4776, Train acc: 75.1323%, Val loss: 0.6420, Val acc: 72.8395%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 52/100, Train loss: 0.4646, Train acc: 75.6614%, Val loss: 0.9838, Val acc: 59.2593%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 53/100, Train loss: 0.5303, Train acc: 72.4868%, Val loss: 0.8240, Val acc: 61.7284%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 54/100, Train loss: 0.5388, Train acc: 73.0159%, Val loss: 0.6218, Val acc: 69.1358%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 55/100, Train loss: 0.3893, Train acc: 81.4815%, Val loss: 0.5897, Val acc: 76.5432%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 56/100, Train loss: 0.4116, Train acc: 81.4815%, Val loss: 0.6107, Val acc: 72.8395%, Best Val loss: 0.5599 Best Val acc: 76.54%
# Epoch 57/100, Train loss: 0.3558, Train acc: 82.5397%, Val loss: 0.5461, Val acc: 77.7778%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 58/100, Train loss: 0.3737, Train acc: 81.4815%, Val loss: 0.5635, Val acc: 75.3086%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 59/100, Train loss: 0.4368, Train acc: 76.7196%, Val loss: 0.6026, Val acc: 72.8395%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 60/100, Train loss: 0.4069, Train acc: 83.0688%, Val loss: 0.7483, Val acc: 64.1975%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 61/100, Train loss: 0.4407, Train acc: 78.3069%, Val loss: 0.5970, Val acc: 74.0741%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 62/100, Train loss: 0.3956, Train acc: 79.3651%, Val loss: 0.5561, Val acc: 75.3086%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 63/100, Train loss: 0.3467, Train acc: 84.6561%, Val loss: 0.6260, Val acc: 70.3704%, Best Val loss: 0.5461 Best Val acc: 77.78%
# Epoch 64/100, Train loss: 0.3645, Train acc: 80.9524%, Val loss: 0.5551, Val acc: 79.0123%, Best Val loss: 0.5461 Best Val acc: 79.01%
# Epoch 65/100, Train loss: 0.3445, Train acc: 86.2434%, Val loss: 0.5368, Val acc: 79.0123%, Best Val loss: 0.5368 Best Val acc: 79.01%
# Epoch 66/100, Train loss: 0.3454, Train acc: 85.1852%, Val loss: 0.5403, Val acc: 79.0123%, Best Val loss: 0.5368 Best Val acc: 79.01%
# Epoch 67/100, Train loss: 0.3474, Train acc: 86.2434%, Val loss: 0.5245, Val acc: 77.7778%, Best Val loss: 0.5245 Best Val acc: 79.01%
# Epoch 68/100, Train loss: 0.3483, Train acc: 84.6561%, Val loss: 0.6209, Val acc: 71.6049%, Best Val loss: 0.5245 Best Val acc: 79.01%
# Epoch 69/100, Train loss: 0.3738, Train acc: 80.4233%, Val loss: 0.5322, Val acc: 79.0123%, Best Val loss: 0.5245 Best Val acc: 79.01%
# Epoch 70/100, Train loss: 0.3641, Train acc: 83.0688%, Val loss: 0.5516, Val acc: 79.0123%, Best Val loss: 0.5245 Best Val acc: 79.01%
# Epoch 71/100, Train loss: 0.3719, Train acc: 81.4815%, Val loss: 0.5903, Val acc: 74.0741%, Best Val loss: 0.5245 Best Val acc: 79.01%
# Epoch 72/100, Train loss: 0.3716, Train acc: 83.0688%, Val loss: 0.5281, Val acc: 80.2469%, Best Val loss: 0.5245 Best Val acc: 80.25%
# Epoch 73/100, Train loss: 0.3609, Train acc: 84.6561%, Val loss: 0.6071, Val acc: 71.6049%, Best Val loss: 0.5245 Best Val acc: 80.25%
# Epoch 74/100, Train loss: 0.3483, Train acc: 86.2434%, Val loss: 0.5244, Val acc: 76.5432%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 75/100, Train loss: 0.3450, Train acc: 85.1852%, Val loss: 0.5347, Val acc: 76.5432%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 76/100, Train loss: 0.3392, Train acc: 87.3016%, Val loss: 0.5311, Val acc: 77.7778%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 77/100, Train loss: 0.3509, Train acc: 84.6561%, Val loss: 0.5381, Val acc: 77.7778%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 78/100, Train loss: 0.3522, Train acc: 85.1852%, Val loss: 0.5336, Val acc: 77.7778%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 79/100, Train loss: 0.3710, Train acc: 84.1270%, Val loss: 0.5628, Val acc: 75.3086%, Best Val loss: 0.5244 Best Val acc: 80.25%
# Epoch 80/100, Train loss: 0.3670, Train acc: 81.4815%, Val loss: 0.5206, Val acc: 79.0123%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 81/100, Train loss: 0.3379, Train acc: 86.7725%, Val loss: 0.5903, Val acc: 74.0741%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 82/100, Train loss: 0.3432, Train acc: 86.7725%, Val loss: 0.5207, Val acc: 79.0123%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 83/100, Train loss: 0.3472, Train acc: 84.6561%, Val loss: 0.5616, Val acc: 75.3086%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 84/100, Train loss: 0.3338, Train acc: 86.7725%, Val loss: 0.5268, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 85/100, Train loss: 0.3280, Train acc: 86.7725%, Val loss: 0.5370, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 86/100, Train loss: 0.3278, Train acc: 87.8307%, Val loss: 0.5455, Val acc: 79.0123%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 87/100, Train loss: 0.3285, Train acc: 86.7725%, Val loss: 0.5344, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 88/100, Train loss: 0.3295, Train acc: 86.2434%, Val loss: 0.5307, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 89/100, Train loss: 0.3274, Train acc: 87.8307%, Val loss: 0.5490, Val acc: 79.0123%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 90/100, Train loss: 0.3297, Train acc: 86.2434%, Val loss: 0.5403, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 91/100, Train loss: 0.3276, Train acc: 86.7725%, Val loss: 0.5303, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 92/100, Train loss: 0.3290, Train acc: 87.3016%, Val loss: 0.5324, Val acc: 76.5432%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 93/100, Train loss: 0.3276, Train acc: 86.7725%, Val loss: 0.5330, Val acc: 76.5432%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 94/100, Train loss: 0.3264, Train acc: 86.7725%, Val loss: 0.5385, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 95/100, Train loss: 0.3249, Train acc: 87.3016%, Val loss: 0.5379, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 96/100, Train loss: 0.3275, Train acc: 86.7725%, Val loss: 0.5361, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 97/100, Train loss: 0.3245, Train acc: 86.7725%, Val loss: 0.5370, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 98/100, Train loss: 0.3267, Train acc: 86.7725%, Val loss: 0.5366, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 99/100, Train loss: 0.3257, Train acc: 86.7725%, Val loss: 0.5367, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%
# Epoch 100/100, Train loss: 0.3273, Train acc: 86.7725%, Val loss: 0.5367, Val acc: 77.7778%, Best Val loss: 0.5206 Best Val acc: 80.25%

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

for i in range(3):
  fig, ax = plt.subplots(1, 2, figsize=(15, 5))

  # Plotting training and validation accuracy
  ax[0].plot(train_accuracies_compare[i])
  ax[0].plot(val_accuracies_compare[i])
  ax[0].set_title('Model Accuracy')
  ax[0].set_xlabel('Epochs')
  ax[0].set_ylabel('Accuracy')
  ax[0].legend(['Train', 'Val'])

  # Plotting training and validation loss
  ax[1].plot(train_losses_compare[i])
  ax[1].plot(val_losses_compare[i])
  ax[1].set_title('Model Loss')
  ax[1].set_xlabel('Epochs')
  ax[1].set_ylabel('Loss')
  ax[1].legend(['Train', 'Val'])

  plt.show()

  print(f'''
      When epochs is {epochs_values[i]}.
      Train accuracy is {train_accuracies_compare[i][-1]:0.4f}% , Train losses is {train_losses_compare[i][-1]:.4f}
      Validation accuracy is {val_accuracies_compare[i][-1]:0.4f}% , Validation losses is {val_losses_compare[i][-1]:.4f}
      Test accuracy is {test_accuracies_compare[i]:0.4f}%' , Test losses is {test_losses_compare[i]:0.4f}'
     ''')
# Out:
#       When epochs is 20.
#       Train accuracy is 73.0159% , Train losses is 0.5215
#       Validation accuracy is 67.9012% , Validation losses is 0.6710
#       Test accuracy is 64.5161%' , Test losses is 0.8076'
#       When epochs is 50.
#       Train accuracy is 76.7196% , Train losses is 0.4360
#       Validation accuracy is 70.3704% , Validation losses is 0.5928
#       Test accuracy is 67.7419%' , Test losses is 0.6009'
#       When epochs is 100.
#       Train accuracy is 86.7725% , Train losses is 0.3273
#       Validation accuracy is 77.7778% , Validation losses is 0.5367
#       Test accuracy is 64.5161%' , Test losses is 0.5376'
